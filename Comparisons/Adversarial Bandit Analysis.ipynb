# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import *


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
graphs = [
            'Random_Sparse_graph',
          'Sioux_Falls',
    'OW'
         ]
n_sto = 0
n_adv = 5
n_hyb = 0
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9,
                                         nb_iterations=1000,
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyb, 
                                         n_rand=0, n_fix=0,
                                         exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                                         gamma_hyb=10.0, time_limit=120)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 81 combination of paths
# Total time to compute costs:0.05 s
#  => The minimal cost is :  22.0
#  => The optimal paths are :  [[8, 12, 18, 10, 16, 1, 6], [4, 3, 11, 18, 10, 16, 1], [16, 10, 18, 12, 4], [12, 4], [1, 16, 10, 18]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# ...

# %% [markdown]
# **Chaniging learning rate strategy**

# %%
n_players_adv = 5
n_random = 0
n_fix = 0
lr_types = range(1, 6)
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i, lr in enumerate(lr_types) : 
    print('Using LR type for adversarial agent  = {}'.format(lr), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=500, n_sto=0, n_adv=n_players_adv, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=5, lr_type_exp2=lr, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=20)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=500, n_sto=0, n_adv=n_players_adv, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=5, lr_type_exp2=lr, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=20)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using LR type for adversarial agent  = 1
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 20 seconds, only 21562 combinations where tested
# Total time to compute costs:20.00 s
#  => The minimal cost is :  77.0
#  => The optimal paths are :  [[8, 5, 6, 7], [11, 9], [4, 1], [12, 10, 9, 6], [10, 9]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# adv1   {'path': [8, 9, 10, 7], 'cost': 21.0}
# ...

# %% [markdown]
# ***

# %%
n_adv_agents = [3,5,8,10]
for n_adv_a in n_adv_agents : 
    print('Number of Adv. Agents = {}'.format(n_adv_a), end='\n')
    summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.9, nb_iterations=100,
                                         n_sto=0, n_adv=n_adv_a, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Number of Adv. Agents = 3
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 146191 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  60.0
#  => The optimal paths are :  [[8, 9, 6, 3, 1], [4, 3, 6, 5], [3, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# adv1   {'path': [8, 9, 6, 3, 1], 'cost': 30.0}
# ...
