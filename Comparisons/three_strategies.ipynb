# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment


# %load_ext autoreload
# %autoreload 2

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 3
n_hyd = 3
n_adv = 3
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=1000, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 15552 combination of paths
# Total time to compute costs:13.61 s
#  => The minimal cost is :  45.0
#  => The optimal paths are :  [[10, 3, 12, 2, 11, 7], [9, 11, 4], [16, 9, 11, 2, 3], [5, 4, 11, 2, 14], [5, 4, 11, 9, 19, 12, 3, 10], [11, 2, 14, 6, 8], [2, 11], [16, 9, 19, 12], [11, 7]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [10, 3, 2, 11, 7], 'cost': 5.0}
# sto2   {'path': [9, 11, 4], 'cost': 4.0}
# sto3   {'path': [16, 9, 19, 12, 3], 'cost': 8.0}
# adv1   {'path': [5, 4, 11, 2, 14], 'cost': 8.0}
# adv2   {'path': [5, 4, 11, 9, 19, 12, 3, 10], 'cost': 11.0}
# adv3   {'path': [11, 2, 14, 6, 8], 'cost': 4.0}
# hyb1   {'path': [2, 3, 12, 19, 9, 11], 'cost': 8.0}
# hyb2   {'path': [16, 9, 19, 12], 'cost': 7.0}
# hyb3   {'path': [11, 7], 'cost': 1.0}
# Final total cost on the network : 56.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 45824 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  300.75974242655593
#  => The optimal paths are :  [[12, 11, 10, 9, 8, 7], [21, 14, 9, 10], [18, 19, 20], [16, 18, 19, 20], [4, 5, 7, 6], [14, 9, 16], [18, 16, 15, 7], [20, 19, 17, 6, 7, 5, 1], [2, 3]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [12, 23, 20, 19, 17, 6, 7], 'cost': 49.370799650978256}
# sto2   {'path': [21, 22, 13, 10], 'cost': 35.27441708495527}
# sto3   {'path': [18, 14, 21, 20], 'cost': 21.96025511299838}
# adv1   {'path': [16, 18, 14, 21, 20], 'cost': 32.497977919123244}
# adv2   {'path': [4, 8, 7, 6], 'cost': 30.190593172336754}
# adv3   {'path': [14, 18, 16], 'cost': 16.06469819399377}
# hyb1   {'path': [18, 16, 9, 8, 4, 3, 2, 0, 1, 5, 7], 'cost': 84.38225929972754}
# hyb2   {'path': [20, 19, 17, 6, 7, 5, 4, 3, 2, 0, 1], 'cost': 61.39981747209831}
# hyb3   {'path': [2, 11, 10, 9, 8, 4, 3], 'cost': 47.66305951267327}
# Final total cost on the network : 378.8038774188848
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 86805 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  164.0
#  => The optimal paths are :  [[9, 6, 5], [5, 6, 9], [10, 7, 4], [1, 3, 6, 9, 11], [2, 6, 10], [9, 12], [10, 7, 6, 5], [10, 9, 8], [6, 3, 1]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [9, 6, 5], 'cost': 12.0}
# sto2   {'path': [5, 6, 9], 'cost': 12.0}
# sto3   {'path': [10, 7, 3, 4], 'cost': 31.0}
# adv1   {'path': [1, 3, 6, 9, 11], 'cost': 33.0}
# adv2   {'path': [2, 3, 4, 7, 10], 'cost': 24.0}
# adv3   {'path': [9, 12], 'cost': 12.0}
# hyb1   {'path': [10, 7, 3, 2, 6, 9, 8, 5], 'cost': 65.0}
# hyb2   {'path': [10, 9, 11, 8], 'cost': 23.0}
# hyb3   {'path': [6, 3, 1], 'cost': 18.0}
# Final total cost on the network : 230.0
# ****************************************************************************************************************************

# %% [markdown]
# ***

# %%
graphs = ['OW']
n_sto = 1
n_hyd = 1
n_adv = 1
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=250, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 129948 combination of paths
# Total time to compute costs:51.05 s
#  => The minimal cost is :  30.0
#  => The optimal paths are :  [[10, 7, 3], [1, 3], [6, 3]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=250, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [10, 7, 3], 'cost': 21.0}
# adv1   {'path': [1, 4, 3], 'cost': 18.0}
# hyb1   {'path': [6, 7, 3], 'cost': 27.0}
# Final total cost on the network : 66.0
# ****************************************************************************************************************************

# %%
graphs = ['OW']
n_sto = 5
n_hyd = 5
n_adv = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=250, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 70763 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  471.0
#  => The optimal paths are :  [[9, 6, 3, 1], [8, 5, 6], [2, 5, 8], [4, 3, 2, 5], [8, 5, 2, 3, 1], [6, 10], [3, 6, 9, 12], [4, 3, 2, 5, 8], [7, 10, 12], [7, 6, 5], [11, 9, 12], [5, 2, 3], [12, 10, 7, 3, 2], [10, 7, 6, 2], [3, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=250, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [9, 6, 3, 4, 1], 'cost': 38.0}
# sto2   {'path': [8, 9, 6], 'cost': 27.0}
# sto3   {'path': [2, 5, 8], 'cost': 37.0}
# sto4   {'path': [4, 3, 2, 5], 'cost': 36.0}
# sto5   {'path': [8, 9, 6, 3, 4, 1], 'cost': 52.0}
# adv1   {'path': [6, 9, 10], 'cost': 24.0}
# adv2   {'path': [3, 6, 9, 12], 'cost': 28.0}
# adv3   {'path': [4, 7, 10, 9, 8], 'cost': 28.0}
# adv4   {'path': [7, 10, 12], 'cost': 5.0}
# adv5   {'path': [7, 6, 5], 'cost': 18.0}
# hyb1   {'path': [11, 8, 5, 2, 3, 1, 4, 7, 6, 9, 10, 12], 'cost': 109.0}
# hyb2   {'path': [5, 8, 9, 6, 2, 3], 'cost': 41.0}
# hyb3   {'path': [12, 10, 9, 8, 5, 2], 'cost': 53.0}
# hyb4   {'path': [10, 6, 3, 2], 'cost': 34.0}
# hyb5   {'path': [3, 2], 'cost': 7.0}
# Final total cost on the network : 537.0
# ****************************************************************************************************************************

# %%
graphs = ['OW']
n_sto = 10
n_hyd = 10
n_adv = 10
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=250, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 42530 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  1191.0
#  => The optimal paths are :  [[8, 5, 6, 7], [3, 6, 9, 12], [2, 5, 8, 11], [2, 3, 1], [12, 10, 7, 4], [1, 3], [10, 9, 8], [8, 5, 2, 3, 4], [6, 2], [10, 9], [11, 8], [4, 1], [8, 11], [8, 5, 2], [8, 5, 6, 7], [12, 9, 6, 5], [9, 6], [11, 9, 12], [1, 4], [9, 6, 3], [11, 8], [5, 2], [6, 3, 1], [7, 6, 5, 8], [3, 1], [8, 5, 6, 7], [12, 9, 6, 5], [8, 9, 6, 3, 1], [10, 7, 4], [6, 9, 11]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=250, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [8, 9, 6, 7], 'cost': 63.0}
# sto2   {'path': [3, 7, 10, 12], 'cost': 17.0}
# sto3   {'path': [2, 6, 9, 11], 'cost': 57.0}
# sto4   {'path': [2, 3, 1], 'cost': 25.0}
# sto5   {'path': [12, 9, 6, 3, 4], 'cost': 58.0}
# sto6   {'path': [1, 4, 3], 'cost': 43.0}
# sto7   {'path': [10, 9, 8], 'cost': 45.0}
# sto8   {'path': [8, 9, 6, 3, 4], 'cost': 82.0}
# sto9   {'path': [6, 2], 'cost': 27.0}
# sto10   {'path': [10, 9], 'cost': 27.0}
# adv1   {'path': [11, 8], 'cost': 6.0}
# adv2   {'path': [4, 1], 'cost': 22.0}
# adv3   {'path': [8, 11], 'cost': 6.0}
# adv4   {'path': [8, 9, 6, 5, 2], 'cost': 92.0}
# adv5   {'path': [8, 5, 2, 3, 7], 'cost': 58.0}
# adv6   {'path': [12, 10, 6, 5], 'cost': 44.0}
# adv7   {'path': [9, 6], 'cost': 6.0}
# adv8   {'path': [11, 9, 12], 'cost': 36.0}
# adv9   {'path': [1, 3, 7, 4], 'cost': 27.0}
# adv10   {'path': [9, 6, 3], 'cost': 13.0}
# hyb1   {'path': [11, 9, 8], 'cost': 42.0}
# hyb2   {'path': [5, 6, 2], 'cost': 18.0}
# hyb3   {'path': [6, 3, 4, 1], 'cost': 39.0}
# hyb4   {'path': [7, 4, 3, 2, 6, 9, 11, 8], 'cost': 68.0}
# hyb5   {'path': [3, 2, 5, 6, 7, 4, 1], 'cost': 106.0}
# hyb6   {'path': [8, 11, 9, 6, 3, 4, 7], 'cost': 49.0}
# hyb7   {'path': [12, 10, 7, 3, 2, 5], 'cost': 44.0}
# hyb8   {'path': [8, 9, 10, 6, 7, 3, 1], 'cost': 96.0}
# hyb9   {'path': [10, 9, 6, 2, 3, 4], 'cost': 82.0}
# hyb10   {'path': [6, 2, 3, 1, 4, 7, 10, 9, 11], 'cost': 94.0}
# Final total cost on the network : 1392.0
# ****************************************************************************************************************************
