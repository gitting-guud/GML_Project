# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment


# %load_ext autoreload
# %autoreload 2

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 3
n_hyd = 3
n_adv = 3
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=1000, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 8 combination of paths
# Total time to compute costs:0.00 s
#  => The minimal cost is :  26.0
#  => The optimal paths are :  [[9, 7, 11, 17, 1], [2, 12, 19], [1, 17, 7], [1, 17], [15, 16], [4, 3], [15, 16], [2, 12, 10], [1, 17, 11]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [9, 7, 17, 1], 'cost': 5.0}
# sto2   {'path': [2, 12, 19], 'cost': 3.0}
# sto3   {'path': [1, 17, 7], 'cost': 6.0}
# adv1   {'path': [1, 17], 'cost': 3.0}
# adv2   {'path': [15, 16], 'cost': 2.0}
# adv3   {'path': [4, 3], 'cost': 1.0}
# hyb1   {'path': [15, 16], 'cost': 2.0}
# hyb2   {'path': [2, 12, 10], 'cost': 3.0}
# hyb3   {'path': [1, 17, 7, 11], 'cost': 7.0}
# Final total cost on the network : 32.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 54055 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  428.6723247778445
#  => The optimal paths are :  [[15, 9, 10], [4, 5, 7, 6, 17, 19], [11, 10, 9], [18, 14, 9, 10, 3, 2, 0], [16, 9, 10, 3], [10, 9, 14, 21], [15, 9], [22, 13, 14, 9], [10, 3, 4, 8]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [15, 9, 10], 'cost': 52.87824084870251}
# sto2   {'path': [4, 8, 7, 6, 17, 19], 'cost': 36.51218994688234}
# sto3   {'path': [11, 2, 3, 4, 8, 9], 'cost': 30.20781201517836}
# adv1   {'path': [18, 14, 21, 22, 23, 12, 11, 2, 0], 'cost': 58.217661684923385}
# adv2   {'path': [16, 9, 8, 4, 3], 'cost': 34.01248732488798}
# adv3   {'path': [10, 11, 2, 0, 1, 5, 7, 6, 17, 19, 21], 'cost': 107.25770880570657}
# hyb1   {'path': [15, 9], 'cost': 40.472551397519666}
# hyb2   {'path': [22, 23, 12, 11, 2, 3, 4, 5, 7, 8, 9], 'cost': 80.5507917850506}
# hyb3   {'path': [10, 3, 2, 0, 1, 5, 7, 6, 17, 15, 9, 8], 'cost': 122.5601036239406}
# Final total cost on the network : 562.669547432792
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 88241 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  191.0
#  => The optimal paths are :  [[1, 3, 6, 9, 11], [12, 9, 8], [7, 6, 9, 11], [4, 3, 2, 5], [9, 12], [5, 6, 7], [12, 10, 7, 3], [8, 11], [1, 4, 3]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [1, 3, 6, 9, 8, 11], 'cost': 43.0}
# sto2   {'path': [12, 10, 9, 8], 'cost': 29.0}
# sto3   {'path': [7, 6, 9, 8, 11], 'cost': 35.0}
# adv1   {'path': [4, 1, 3, 6, 5], 'cost': 38.0}
# adv2   {'path': [9, 10, 12], 'cost': 11.0}
# adv3   {'path': [5, 6, 7], 'cost': 18.0}
# hyb1   {'path': [12, 9, 6, 2, 3], 'cost': 34.0}
# hyb2   {'path': [8, 11], 'cost': 2.0}
# hyb3   {'path': [1, 3], 'cost': 22.0}
# Final total cost on the network : 232.0
# ****************************************************************************************************************************
