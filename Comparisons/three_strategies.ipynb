# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment


# %load_ext autoreload
# %autoreload 2

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 3
n_hyd = 3
n_adv = 3
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=1000, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 4 combination of paths
# Total time to compute costs:0.00 s
#  => The minimal cost is :  53.0
#  => The optimal paths are :  [[19, 4, 15, 16, 2, 3, 13, 8], [1, 7, 19, 4, 15, 16, 2, 3, 13, 8], [10, 2, 3], [4, 15, 16, 11], [4, 15, 16, 2, 3, 13], [8, 13, 3, 2], [19, 4, 6], [10, 2, 3], [14, 2, 16, 15, 4, 19, 18]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [19, 4, 15, 16, 2, 3, 13, 8], 'cost': 9.0}
# sto2   {'path': [1, 7, 19, 4, 15, 16, 2, 3, 13, 8], 'cost': 10.0}
# sto3   {'path': [10, 2, 3], 'cost': 4.0}
# adv1   {'path': [4, 15, 16, 11], 'cost': 5.0}
# adv2   {'path': [4, 15, 16, 2, 3, 13], 'cost': 7.0}
# adv3   {'path': [8, 13, 3, 2], 'cost': 3.0}
# hyb1   {'path': [19, 4, 6], 'cost': 3.0}
# hyb2   {'path': [10, 2, 3], 'cost': 4.0}
# hyb3   {'path': [14, 2, 16, 15, 4, 19, 7, 1, 18], 'cost': 10.0}
# Final total cost on the network : 55.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 54130 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  264.4741643775962
#  => The optimal paths are :  [[14, 9, 15, 17], [21, 14, 9], [23, 12, 11, 10, 9, 8], [22, 13, 10], [5, 7, 15, 16, 18], [13, 14, 18], [16, 9], [3, 10, 9, 14, 21], [3, 4, 8]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [14, 18, 16, 15, 17], 'cost': 27.538270138836754}
# sto2   {'path': [21, 14, 9], 'cost': 22.868727633772437}
# sto3   {'path': [23, 12, 11, 2, 3, 4, 8], 'cost': 40.89637752592322}
# adv1   {'path': [22, 13, 14, 9, 15, 16, 18, 19, 21, 20, 23, 12, 11, 2, 0, 1, 5, 7, 8, 4, 3, 10], 'cost': 204.72751294150933}
# adv2   {'path': [5, 7, 8, 4, 3, 2, 11, 12, 23, 20, 19, 17, 15, 9, 10, 13, 22, 21, 14, 18], 'cost': 185.31616484148438}
# adv3   {'path': [13, 22, 21, 19, 20, 23, 12, 11, 10, 3, 2, 0, 1, 5, 4, 8, 7, 15, 16, 9, 14, 18], 'cost': 212.97852122194615}
# hyb1   {'path': [16, 9], 'cost': 16.308017150740422}
# hyb2   {'path': [3, 10, 9, 15, 17, 19, 21], 'cost': 64.85409616895215}
# hyb3   {'path': [3, 10, 11, 12, 23, 22, 21, 20, 19, 18, 16, 15, 17, 6, 7, 5, 4, 8], 'cost': 151.62823064183448}
# Final total cost on the network : 927.1159182649994
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 106715 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  118.0
#  => The optimal paths are :  [[9, 6, 5], [10, 7], [7, 3, 2], [9, 10], [11, 9, 6], [3, 7], [9, 6], [7, 6, 2], [7, 10]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [9, 8, 5], 'cost': 35.0}
# sto2   {'path': [10, 7], 'cost': 3.0}
# sto3   {'path': [7, 6, 2], 'cost': 27.0}
# adv1   {'path': [9, 11, 8, 5, 2, 3, 7, 6, 10], 'cost': 76.0}
# adv2   {'path': [11, 8, 5, 2, 3, 1, 4, 7, 10, 12, 9, 6], 'cost': 106.0}
# adv3   {'path': [3, 6, 2, 5, 8, 11, 9, 12, 10, 7], 'cost': 132.0}
# hyb1   {'path': [9, 6], 'cost': 3.0}
# hyb2   {'path': [7, 3, 2], 'cost': 25.0}
# hyb3   {'path': [7, 3, 6, 5, 8, 11, 9, 12, 10], 'cost': 116.0}
# Final total cost on the network : 523.0
# ****************************************************************************************************************************

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 0
n_hyd = 0
n_adv = 1
for graph in graphs :
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, 
                                         number_vertices=20, 
                                         dropout_edge_rate=0.9,
                                         nb_iterations=1000, 
                                         n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 1 combination of paths
# Total time to compute costs:0.00 s
#  => The minimal cost is :  1.0
#  => The optimal paths are :  [[19, 3]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# [1.]
# ..\Agents\Exp2_agent.py:57: RuntimeWarning: invalid value encountered in true_divide
#   self.new_proba_over_arms = self.new_proba_over_arms / self.new_proba_over_arms.sum()
# [nan]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-98811598149c> in <module>
#      11                                          n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyd,
#      12                        n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
# ---> 13                       gamma_hyb=10.0, time_limit=60)
#
# ~\Documents\GitHub\MVA_RecVis2019\GML_Project\run_experiment.py in run_experiment(graph_type, number_vertices, dropout_edge_rate, nb_iterations, n_sto, n_adv, n_hyb, n_rand, n_fix, exploration_parameter_stoc, eta_hyb, Bt_hyb, use_adaptif_lr_hyb, gamma_hyb, time_limit)
#     107                     agent_class = Fixed_Path_agent(arms=arms_possible[agent_name], index_arm=int(agent_name[3]))
#     108
# --> 109                 arm_to_play = agent_class.step()
#     110                 list_arms_pulled.append(arm_to_play)
#     111
#
# ~\Documents\GitHub\MVA_RecVis2019\GML_Project\Agents\Exp2_agent.py in step(self)
#      18     def step(self):
#      19         print( self.proba_over_arms)
# ---> 20         index = np.random.choice(len(self.arms_adv), p= self.proba_over_arms)
#      21         arm_to_play = self.arms_adv[index]
#      22         return arm_to_play
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN
