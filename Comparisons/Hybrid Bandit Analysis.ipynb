# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment

# %load_ext autoreload
# %autoreload 2

# %%
graphs = ['OW']
n_hyd = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=100, n_sto=0, n_adv=0, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 124474 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  69.0
#  => The optimal paths are :  [[3, 6, 9, 12], [7, 6, 5], [3, 7], [10, 9], [1, 3]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', style=ProgressStyle(description_width='initial')…
# Paths found by the agents :
# hyb1   {'path': [3, 7, 10, 6, 9, 12], 'cost': 49.0}
# hyb2   {'path': [7, 3, 6, 5], 'cost': 34.0}
# hyb3   {'path': [3, 6, 9, 12, 10, 7], 'cost': 30.0}
# hyb4   {'path': [10, 6, 9], 'cost': 19.0}
# hyb5   {'path': [1, 3], 'cost': 11.0}
# Final total cost on the network : 143.0
# ****************************************************************************************************************************
