# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment

# %load_ext autoreload
# %autoreload 2

# %%
graphs = [
            'Random_Sparse_graph',
          'Sioux_Falls',
    'OW'
         ]
n_hyd = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=500, n_sto=0, n_adv=0, n_hyb=n_hyd, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=120)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 1920 combination of paths
# Total time to compute costs:1.00 s
#  => The minimal cost is :  20.0
#  => The optimal paths are :  [[2, 17, 5, 11, 1, 8, 15], [8, 1, 11], [7, 8, 1, 12], [18, 16, 14, 17], [4, 12, 1, 11, 5, 17, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# ...

# %%
n_hyd_agents = [3,5,8,10]
for n_hyd_a in n_hyd_agents : 
    print('Number of Adv. Agents = {}'.format(n_hyd_a), end='\n')
    summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.9, nb_iterations=100,
                                         n_sto=0, n_adv=0, n_hyb=n_hyd_a, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Number of Adv. Agents = 3
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 127518 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  38.0
#  => The optimal paths are :  [[9, 6, 2], [10, 7, 3, 2], [3, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# hyb1   {'path': [9, 10, 6, 2], 'cost': 31.0}
# ...
