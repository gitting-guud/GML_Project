# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import run_experiment


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Sto + Adv

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 5
n_adv = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=100, n_sto=n_sto, n_adv=n_adv, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 1 combination of paths
# Total time to compute costs:0.00 s
#  => The minimal cost is :  56.0
#  => The optimal paths are :  [[14, 17, 1, 11], [6, 2, 17, 1, 12, 9], [14, 3], [6, 2, 17, 14], [12, 1], [1, 17, 14], [8, 2, 17, 1, 12, 9], [11, 1, 17, 2, 6], [17, 14, 3], [14, 17, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', style=ProgressStyle(description_width='initial')…
# Paths found by the agents :
# sto1   {'path': [14, 17, 1, 11], 'cost': 6.0}
# sto2   {'path': [6, 2, 17, 1, 12, 9], 'cost': 12.0}
# sto3   {'path': [14, 3], 'cost': 1.0}
# sto4   {'path': [6, 2, 17, 14], 'cost': 7.0}
# sto5   {'path': [12, 1], 'cost': 1.0}
# adv1   {'path': [1, 17, 14], 'cost': 2.0}
# adv2   {'path': [8, 2, 17, 1, 12, 9], 'cost': 11.0}
# adv3   {'path': [11, 1, 17, 2, 6], 'cost': 5.0}
# adv4   {'path': [17, 14, 3], 'cost': 4.0}
# adv5   {'path': [14, 17, 2], 'cost': 7.0}
# Final total cost on the network : 56.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 45140 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  412.23934558171425
#  => The optimal paths are :  [[12, 23, 20, 21], [17, 19, 21, 22], [12, 23, 20, 19], [4, 8, 9, 14], [1, 5, 4, 8, 9, 14, 21], [19, 17, 6, 7, 5, 4], [16, 15, 7, 6], [9, 10, 3, 2], [1, 0, 2, 11, 12], [1, 0, 2, 11, 12]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', style=ProgressStyle(description_width='initial')…
# Paths found by the agents :
# sto1   {'path': [12, 23, 20, 21], 'cost': 63.040680082361426}
# sto2   {'path': [17, 19, 21, 22], 'cost': 28.597677670802053}
# sto3   {'path': [12, 23, 20, 19], 'cost': 66.90880994593851}
# sto4   {'path': [4, 8, 9, 14], 'cost': 29.056214039433492}
# sto5   {'path': [1, 5, 7, 6, 17, 19, 21], 'cost': 48.364331644640686}
# adv1   {'path': [19, 17, 6, 7, 5, 4], 'cost': 46.53282935551082}
# adv2   {'path': [16, 9, 15, 17, 6], 'cost': 43.68266470343476}
# adv3   {'path': [9, 10, 11, 2], 'cost': 38.05528854798178}
# adv4   {'path': [1, 0, 2, 11, 12], 'cost': 38.12518030063331}
# adv5   {'path': [1, 0, 2, 11, 12], 'cost': 38.12518030063331}
# Final total cost on the network : 440.4888565913701
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 98406 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  249.0
#  => The optimal paths are :  [[5, 6, 9, 12], [7, 6, 5, 8], [11, 9, 12], [12, 10, 7], [10, 6, 5], [12, 9, 6, 3, 1], [6, 9, 12], [9, 8, 11], [3, 2, 5], [2, 6, 7]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', style=ProgressStyle(description_width='initial')…
# Paths found by the agents :
# sto1   {'path': [5, 6, 10, 12], 'cost': 26.0}
# sto2   {'path': [7, 10, 9, 8], 'cost': 21.0}
# sto3   {'path': [11, 8, 9, 10, 12], 'cost': 22.0}
# sto4   {'path': [12, 10, 7], 'cost': 8.0}
# sto5   {'path': [10, 6, 5], 'cost': 22.0}
# adv1   {'path': [12, 9, 6, 3, 1], 'cost': 33.0}
# adv2   {'path': [6, 7, 10, 12], 'cost': 19.0}
# adv3   {'path': [9, 8, 11], 'cost': 11.0}
# adv4   {'path': [3, 6, 2, 5], 'cost': 27.0}
# adv5   {'path': [2, 3, 7], 'cost': 16.0}
# Final total cost on the network : 205.0
# ****************************************************************************************************************************

# %% [markdown]
# # Re experiment sto +adv on OW

# %%
graphs = ['OW']
n_sto = 5
n_adv = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=500, n_sto=n_sto, n_adv=n_adv, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 91764 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  177.0
#  => The optimal paths are :  [[12, 9, 11], [10, 9, 11], [4, 7, 10], [1, 3, 6, 9, 12], [6, 3], [9, 10], [6, 2], [10, 12], [9, 8], [1, 4]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=500, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [12, 10, 9, 11], 'cost': 25.0}
# sto2   {'path': [10, 9, 11], 'cost': 30.0}
# sto3   {'path': [4, 7, 10], 'cost': 10.0}
# sto4   {'path': [1, 4, 7, 10, 12], 'cost': 34.0}
# sto5   {'path': [6, 3], 'cost': 7.0}
# adv1   {'path': [9, 10], 'cost': 18.0}
# adv2   {'path': [6, 5, 2], 'cost': 20.0}
# adv3   {'path': [10, 12], 'cost': 4.0}
# adv4   {'path': [9, 8], 'cost': 9.0}
# adv5   {'path': [1, 4], 'cost': 22.0}
# Final total cost on the network : 179.0
# ****************************************************************************************************************************

# %% [markdown]
# # adv vs hybrid

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 0
n_adv = 3
n_hyb = 3
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=1000, n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyb, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                      gamma_hyb=1.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 32 combination of paths
# Total time to compute costs:0.02 s
#  => The minimal cost is :  41.0
#  => The optimal paths are :  [[16, 4, 6, 15, 17, 3, 11, 5], [13, 14, 10, 17, 15, 6], [9, 11, 3, 17, 15, 6, 4], [5, 11, 9, 13, 14, 10], [8, 17, 15], [9, 13, 14, 10, 17, 15, 6, 4, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# adv1   {'path': [16, 4, 6, 15, 17, 3, 11, 5], 'cost': 10.0}
# adv2   {'path': [13, 14, 10, 17, 15, 6], 'cost': 10.0}
# adv3   {'path': [9, 11, 3, 17, 15, 6, 4], 'cost': 17.0}
# hyb1   {'path': [5, 11, 3, 17, 10], 'cost': 8.0}
# hyb2   {'path': [8, 17, 15], 'cost': 2.0}
# hyb3   {'path': [9, 11, 3, 17, 15, 6, 4, 2], 'cost': 18.0}
# Final total cost on the network : 65.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 67649 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  107.24681528271563
#  => The optimal paths are :  [[5, 7], [14, 18], [8, 9, 14, 18], [11, 10], [13, 10, 3, 4], [22, 21, 19, 17, 15]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# adv1   {'path': [5, 7], 'cost': 14.690955002063726}
# adv2   {'path': [14, 18], 'cost': 4.326212079332105}
# adv3   {'path': [8, 9, 14, 18], 'cost': 37.453485695945076}
# hyb1   {'path': [11, 10], 'cost': 13.735155648868583}
# hyb2   {'path': [13, 14, 9, 10, 11, 2, 0, 1, 5, 7, 8, 4], 'cost': 125.99198582566898}
# hyb3   {'path': [22, 21, 14, 9, 8, 4, 3, 2, 0, 1, 5, 7, 6, 17, 15], 'cost': 99.09103372704043}
# Final total cost on the network : 295.2888279789189
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 123858 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  103.0
#  => The optimal paths are :  [[12, 10, 7, 4], [10, 9, 8], [9, 8], [9, 6, 7, 10], [12, 9, 6, 3, 1], [4, 7, 10]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# adv1   {'path': [12, 10, 7, 4], 'cost': 12.0}
# adv2   {'path': [10, 9, 8], 'cost': 27.0}
# adv3   {'path': [9, 8], 'cost': 9.0}
# hyb1   {'path': [9, 10], 'cost': 18.0}
# hyb2   {'path': [12, 9, 6, 3, 1], 'cost': 33.0}
# hyb3   {'path': [4, 3, 7, 6, 9, 12, 10], 'cost': 42.0}
# Final total cost on the network : 141.0
# ****************************************************************************************************************************

# %% [markdown]
# # Hyd vs Sto

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 5
n_adv = 0
n_hyb = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=1000, n_sto=n_sto, n_adv=n_adv, n_hyb=n_hyb, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 86448 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  35.0
#  => The optimal paths are :  [[16, 10, 12], [1, 17, 9, 7], [7, 3, 4], [16, 10, 17], [19, 16, 14], [16, 10, 8, 7, 3, 4], [9, 5, 10, 16], [9, 17], [8, 10, 16, 14, 2], [12, 10, 19, 16, 14, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [16, 10, 12], 'cost': 4.0}
# sto2   {'path': [1, 17, 9, 7], 'cost': 3.0}
# sto3   {'path': [7, 3, 4], 'cost': 2.0}
# sto4   {'path': [16, 10, 17], 'cost': 5.0}
# sto5   {'path': [19, 10, 16, 14], 'cost': 5.0}
# hyb1   {'path': [16, 10, 5, 9, 7, 3, 4], 'cost': 9.0}
# hyb2   {'path': [9, 8, 10, 16], 'cost': 3.0}
# hyb3   {'path': [9, 10, 17], 'cost': 3.0}
# hyb4   {'path': [8, 7, 9, 5, 10, 16, 14, 2], 'cost': 8.0}
# hyb5   {'path': [12, 10, 16, 14, 2], 'cost': 6.0}
# Final total cost on the network : 48.0
# ****************************************************************************************************************************
# Using the graph : Sioux_Falls
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 48317 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  221.65234330798168
#  => The optimal paths are :  [[0, 2, 11, 12, 23, 20], [21, 19, 17, 6], [23, 20, 21, 14], [11, 10, 13], [19, 18], [13, 10, 3, 4], [19, 17, 15], [4, 8, 9], [22, 21], [0, 1, 5, 7, 6, 17, 19, 21]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [0, 2, 3, 10, 13, 22, 23, 20], 'cost': 53.69390665667892}
# sto2   {'path': [21, 19, 17, 6], 'cost': 14.036546452378435}
# sto3   {'path': [23, 20, 19, 18, 14], 'cost': 33.68499528563263}
# sto4   {'path': [11, 10, 13], 'cost': 27.426441337364537}
# sto5   {'path': [19, 18], 'cost': 9.515249398501574}
# hyb1   {'path': [13, 10, 9, 8, 4], 'cost': 41.433297524869396}
# hyb2   {'path': [19, 17, 15], 'cost': 7.426064942831618}
# hyb3   {'path': [4, 5, 1, 0, 2, 11, 10, 9], 'cost': 63.16537475417928}
# hyb4   {'path': [22, 23, 20, 21], 'cost': 19.725389419891993}
# hyb5   {'path': [0, 1, 5, 7, 15, 16, 18, 19, 20, 23, 22, 21], 'cost': 107.02139594668567}
# Final total cost on the network : 377.1286617190141
# ****************************************************************************************************************************
# Using the graph : OW
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 60 seconds, only 87507 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  343.0
#  => The optimal paths are :  [[6, 3, 4], [8, 5, 2, 3, 4], [1, 3, 2, 5, 8], [8, 5, 2, 3, 4], [7, 6, 5, 8], [3, 6, 9, 11], [4, 3, 6], [11, 8], [8, 9, 6, 3, 1], [3, 2, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=1000, style=ProgressStyle(description_width=…
# Paths found by the agents :
# sto1   {'path': [6, 3, 4], 'cost': 21.0}
# sto2   {'path': [8, 9, 6, 3, 4], 'cost': 58.0}
# sto3   {'path': [1, 3, 6, 9, 8], 'cost': 49.0}
# sto4   {'path': [8, 9, 6, 3, 4], 'cost': 58.0}
# sto5   {'path': [7, 6, 9, 8], 'cost': 30.0}
# hyb1   {'path': [3, 7, 6, 9, 8, 11], 'cost': 44.0}
# hyb2   {'path': [4, 3, 6], 'cost': 21.0}
# hyb3   {'path': [11, 9, 6, 5, 8], 'cost': 46.0}
# hyb4   {'path': [8, 5, 2, 6, 10, 7, 3, 1], 'cost': 69.0}
# hyb5   {'path': [3, 6], 'cost': 14.0}
# Final total cost on the network : 410.0
# ****************************************************************************************************************************
