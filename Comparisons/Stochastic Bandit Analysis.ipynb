# %% [markdown]
# <h2><big><center>Analysis of Interactions</center></big></h2>
# <h3><big><center>One strategy</center></big></h3>
#
#
# **ALGORITHM**:  Stochastic Semi_Bandits

# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <h4 style="color:blue;"><big>Running simulations on an Environement with only stochastic agents</big></h4>

# %% [markdown]
# **Changing graph structure**

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_sto = 5
for graph in graphs : 
    print('Using the graph : '+ graph, end='\n')
    summary_experiences = run_experiment(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9, nb_iterations=100, n_sto=n_sto, n_adv=0, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Using the graph : Random_Sparse_graph
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 1 combination of paths
# Total time to compute costs:0.00 s
#  => The minimal cost is :  17.0
#  => The optimal paths are :  [[5, 8], [2, 19, 7, 3, 1, 6, 5, 8], [9, 4, 2, 19], [11, 1, 6], [7, 3, 1, 6, 5]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# sto1   {'path': [5, 8], 'cost': 1.0}
# ...

# %% [markdown]
# **Changing the number of stochastic agents**

# %%
n_sto_agents = [5, 10, 20]
for n_sto_a in n_sto_agents : 
    print('Number of Sto. Agents = {}'.format(n_sto_a), end='\n')
    summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.9, nb_iterations=40, n_sto=n_sto_a, n_adv=0, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=300)
# Out:
# Number of Sto. Agents = 5
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 300 seconds, only 637340 combinations where tested
# Total time to compute costs:300.00 s
#  => The minimal cost is :  93.0
#  => The optimal paths are :  [[1, 3, 2, 5], [6, 9, 8], [6, 2], [9, 6, 3, 1], [2, 3, 7]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# sto1   {'path': [1, 3, 2, 5], 'cost': 29.0}
# ...

# %% [markdown]
# **Changing the Exploration parameter**

# %%
explor_params = [0., 1., 1.5, 3, 5]
for exp_param in explor_params : 
    print('Exploration parameter = {}'.format(exp_param), end='\n')
    summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.9, nb_iterations=40, n_sto=7, n_adv=0, n_hyb=0, 
                       n_rand=0, n_fix=0, exploration_parameter_stoc=exp_param, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=60)
# Out:
# Exploration parameter = 0.0
# => Agents Created
# Time depassed 60 seconds, only 55291 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  88.0
#  => The optimal paths are :  [[1, 3, 6], [10, 12], [6, 5], [9, 10], [10, 7, 3], [5, 2, 3, 7], [4, 1]]
# ...
# Exploration parameter = 1.0
# => Agents Created
# Time depassed 60 seconds, only 58745 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  131.0
#  => The optimal paths are :  [[10, 9], [3, 7], [7, 6], [6, 7], [5, 6, 7, 10], [1, 3, 6, 9, 8], [8, 9, 6, 3, 4]]
# ...
# Exploration parameter = 1.5
# => Agents Created
# Time depassed 60 seconds, only 52123 combinations where tested
# Total time to compute costs:60.00 s
#  => The minimal cost is :  182.0
#  => The optimal paths are :  [[5, 2], [11, 9, 6, 3, 4], [7, 3, 1], [12, 9, 6, 3, 1], [2, 6, 5, 8, 11], [10, 7, 6], [8, 11, 9, 6, 3]]
# ...
# Exploration parameter = 3
# => Agents Created
# ...

# %% [markdown]
# **Adding Agents with fixed path**

# %%
n_fix_agents = [1, 2, 5, 8, 10]
for n_fixx in n_fix_agents : 
    print('Number of agents with fixed path = {}'.format(n_fixx), end='\n')
    summary_experiences = run_experiment(graph_type='Random_Sparse_graph', number_vertices=20, dropout_edge_rate=0.8, nb_iterations=40, n_sto=5, n_adv=0, n_hyb=0, 
                       n_rand=0, n_fix=n_fixx, exploration_parameter_stoc=1.5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=40)
# Out:
# Number of agents with fixed path = 1
# => Agents Created
# Time depassed 40 seconds, only 28093 combinations where tested
# Total time to compute costs:40.00 s
#  => The minimal cost is :  16.0
#  => The optimal paths are :  [[6, 13, 14], [13, 3, 11, 2], [3, 17, 9], [8, 6, 11], [2, 11, 6], [19, 7, 10, 1]]
# ...
# Number of agents with fixed path = 2
# => Agents Created
# Time depassed 40 seconds, only 23054 combinations where tested
# Total time to compute costs:40.00 s
#  => The minimal cost is :  16.0
#  => The optimal paths are :  [[2, 1, 10, 15], [12, 15], [6, 17, 15, 12], [16, 3, 6, 2], [16, 4], [10, 1, 19, 17], [19, 18, 10]]
# ...
# Number of agents with fixed path = 5
# => Agents Created
# Time depassed 40 seconds, only 22277 combinations where tested
# Total time to compute costs:40.00 s
#  => The minimal cost is :  33.0
# ...

# %% [markdown]
# **Adding Agents with random paths**

# %%
n_rnd_agents = [1, 2, 5, 8, 10]
for n_randx in n_rnd_agents : 
    print('Number of agents with fixed path = {}'.format(n_randx), end='\n')
    summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.5, nb_iterations=40, n_sto=5, n_adv=0, n_hyb=0, 
                       n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=40)
# Out:
# Number of agents with fixed path = 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6cc1bec58e61> in <module>()
#       2 for n_randx in n_rnd_agents :
#       3     print('Number of agents with fixed path = {}'.format(n_randx), end='\n')
# ----> 4     summary_experiences = run_experiment(graph_type='OW', number_vertices=20, dropout_edge_rate=0.5, nb_iterations=40, n_sto=5, n_adv=0, n_hyb=0,
#       5                        n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
#       6                       gamma_hyb=10.0, time_limit=40)
#
# NameError: name 'run_experiment' is not defined

# %%
n_rnd_agents = [3]
for n_randx in n_rnd_agents : 
    print('Number of agents with fixed path = {}'.format(n_randx), end='\n')
    summary_experiences = run_experiment(graph_type='Random_Sparse_graph', number_vertices=20, dropout_edge_rate=0.9, nb_iterations=40, n_sto=3, n_adv=0, n_hyb=0, 
                       n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                      gamma_hyb=10.0, time_limit=10)
# Out:
# Number of agents with fixed path = 3
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Agents creation, random (start, destination) assignment and all possible paths computation ...
# Agents creation, random (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 10 seconds, only 15078 combinations where tested
# Total time to compute costs:10.00 s
#  => The minimal cost is :  15.0
#  => The optimal paths are :  [[6, 7], [11, 16, 17, 9, 5], [10, 15, 17, 16], [1, 6, 7], [6, 12, 19], [5, 9, 14, 1]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# ...

# %%
n_players_sto = 1
n_random = 10
n_fix = 2
exploration_params = [1, 2, 5, 10, 12]
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i,exp_pa in enumerate(exploration_params) : 
    print('Using exp param for stochatic agent  = {}'.format(exp_pa), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=500, n_sto=n_players_sto, n_adv=0, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=exp_pa, lr_type_exp2=2, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=10)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=500, n_sto=n_players_sto, n_adv=0, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=exp_pa, lr_type_exp2=2, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=10)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using exp param for stochatic agent  = 1
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 10 seconds, only 6919 combinations where tested
# Total time to compute costs:10.00 s
#  => The minimal cost is :  274.0
#  => The optimal paths are :  [[4, 3, 6], [4, 3, 2], [12, 9, 6, 2], [6, 5], [11, 8, 5, 2], [3, 7], [6, 9, 11], [1, 3, 6, 10], [5, 6, 9, 12], [12, 10], [10, 12], [11, 9, 10], [11, 8, 9, 6, 7]]
# Oracle calculations ==> Global optimal paths and costs : Done
# ...

# %%
n_players_sto = 5
n_random = 0
n_fix = 0
exploration_params = [1, 5, 10, 12]
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i,exp_pa in enumerate(exploration_params) : 
    print('Using exp param for stochatic agent  = {}'.format(exp_pa), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=500, n_sto=n_players_sto, n_adv=0, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=exp_pa, lr_type_exp2=2, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=10)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=500, n_sto=n_players_sto, n_adv=0, n_hyb=0, 
                                   n_rand=n_random, n_fix=n_fix, exploration_parameter_stoc=exp_pa, lr_type_exp2=2, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=10)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using exp param for stochatic agent  = 1
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 10 seconds, only 10174 combinations where tested
# Total time to compute costs:10.00 s
#  => The minimal cost is :  90.0
#  => The optimal paths are :  [[11, 9, 6, 7], [6, 2], [5, 6, 10, 12], [11, 8, 9, 10, 12], [3, 1]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# ...
# Paths found by the agents :
# ...
