# %%
import sys
sys.path.insert(0, '../')

import numpy as np
import matplotlib.pyplot as plt
from run_experiment import *


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **Comparing the behavior of algorithms together in different graphs**

# %%
graphs = ['Random_Sparse_graph', 'Sioux_Falls', 'OW']
n_players = 1
for graph in graphs : 
    g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.9)
    print('Using the graph : '+ graph, end='\n')
    summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                           n_rand=0, n_fix=0, exploration_parameter_stoc=5, lr_type_exp2=3, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                        gamma_hyb=1., time_limit=60)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using the graph : Random_Sparse_graph
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Testing 3300 combination of paths
# Total time to compute costs:4.98 s
#  => The minimal cost is :  7.0
#  => The optimal paths are :  [[9, 17], [8, 17, 3, 12, 10], [8, 5, 2]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', style=ProgressStyle(description_width='initial')…
# Paths found by the agents :
# sto1   {'path': [9, 17], 'cost': 1.0}
# adv1   {'path': [8, 17, 3, 12, 10], 'cost': 5.0}
# hyb1   {'path': [8, 17, 7, 13, 19, 10, 14, 5, 2], 'cost': 9.0}
# Final total cost on the network : 15.0
# ****************************************************************************************************************************
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using the graph : Sioux_Falls
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-d0bcea3d67eb> in <module>()
#       6     summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players,
#       7                            n_rand=0, n_fix=0, exploration_parameter_stoc=5, lr_type_exp2=3, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
# ----> 8                         gamma_hyb=1., time_limit=60)
#
# ~\Documents\GitHub\GML_Project\run_experiment.py in run_experiment_compar(g, adj_matrix, all_edges, assignement_type, assignement_dests, nb_iterations, n_sto, n_adv, n_hyb, n_rand, n_fix, exploration_parameter_stoc, lr_type_exp2, eta_hyb, Bt_hyb, use_adaptif_lr_hyb, gamma_hyb, time_limit)
#      75     print("-------------------------------------------------------------------------------------------")
#      76     print("Oracle calculations ==> Global optimal paths and costs...")
# ---> 77     min_cost, opt_path = assignement.get_optimal_paths(combinatorial=True, time_limit=time_limit)
#      78     opt_path_agents = cost_calculator(list_arms_pulled=opt_path, adj_matrix= adj_matrix).return_costs()[0]
#      79     print("Oracle calculations ==> Global optimal paths and costs : Done")
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in get_optimal_paths(self, combinatorial, time_limit)
#     170             for list_arms_pulled_ in paths_combinations:
#     171                 j+=1
# --> 172                 costs = cost_calculator(list_arms_pulled=list(list_arms_pulled_), adj_matrix= self.adj_matrix).return_costs()[0]
#     173                 total_cost = sum(map(lambda x: x['cost'], list(costs.values())))
#     174                 total_costs.append(total_cost)
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in return_costs(self)
#     261         - the costs of each edge at each hop (hop = step towards the destination)
#     262         """
# --> 263         costs = self.cost_calculation()
#     264         results = {}
#     265         for i, arm in enumerate(self.list_arms):
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in cost_calculation(self)
#     240         for j in range(self.list_arms_padded.shape[1]-1):
#     241             self.reset()
# --> 242             edges_time_j_jplusone = self.list_arms_padded[:,[j,j+1]]
#     243             for i, row in enumerate(edges_time_j_jplusone) :
#     244                 row_inversed = row[::-1]
#
# KeyboardInterrupt:

# %% [markdown]
# **Using Adaptif learning rate for Hybrid agent**

# %%
n_players = 2
Adaptif_learning = [False, True]
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i, al_ in enumerate(Adaptif_learning) : 
    print('Using Adaptif learning  = {}'.format(al_), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=al_,
                                gamma_hyb=1., time_limit=40)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=al_,
                                gamma_hyb=1., time_limit=40)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using Adaptif learning  = False
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 40 seconds, only 15433 combinations where tested
# Total time to compute costs:40.01 s
#  => The minimal cost is :  131.0
#  => The optimal paths are :  [[12, 9, 6], [3, 6, 9], [1, 3, 6, 9, 11], [12, 10, 7, 4, 1], [7, 3, 2], [12, 10, 6, 5]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=40, style=ProgressStyle(description_width='i…
# Paths found by the agents :
# sto1   {'path': [12, 10, 9, 6], 'cost': 23.0}
# sto2   {'path': [3, 6, 9], 'cost': 10.0}
# adv1   {'path': [1, 4, 3, 7, 10, 6, 2, 5, 8, 9, 11], 'cost': 106.0}
# adv2   {'path': [12, 9, 11, 8, 5, 2, 6, 3, 7, 4, 1], 'cost': 121.0}
# hyb1   {'path': [7, 10, 12, 9, 11, 8, 5, 6, 3, 2], 'cost': 67.0}
# hyb2   {'path': [12, 9, 10, 7, 4, 1, 3, 6, 2, 5], 'cost': 108.0}
# Final total cost on the network : 435.0
# ****************************************************************************************************************************
# Using Adaptif learning  = True
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 40 seconds, only 35976 combinations where tested
# Total time to compute costs:40.00 s
#  => The minimal cost is :  131.0
#  => The optimal paths are :  [[12, 9, 6], [3, 6, 9], [1, 3, 6, 9, 11], [12, 10, 7, 4, 1], [7, 3, 2], [12, 10, 6, 5]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=40, style=ProgressStyle(description_width='i…
# Paths found by the agents :
# sto1   {'path': [12, 10, 6], 'cost': 32.0}
# sto2   {'path': [3, 6, 9], 'cost': 10.0}
# adv1   {'path': [1, 4, 7, 3, 2, 5, 6, 10, 12, 9, 11], 'cost': 102.0}
# adv2   {'path': [12, 10, 6, 9, 11, 8, 5, 2, 3, 7, 4, 1], 'cost': 114.0}
# hyb1   {'path': [7, 10, 9, 11, 8, 5, 6, 3, 2], 'cost': 78.0}
# hyb2   {'path': [12, 10, 7, 4, 1, 3, 2, 6, 9, 11, 8, 5], 'cost': 84.0}
# Final total cost on the network : 420.0
# ****************************************************************************************************************************

# %% [markdown]
# **Impact of gamma parameter for Hybrid agent**

# %%
n_players = 4
gammas = [0.5, 1, 3, 7, 10]
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i, gamma in enumerate(gammas) : 
    print('Using Gamma for hybrid agents  = {}'.format(gamma), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=500, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=gamma, time_limit=1)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=500, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=gamma, time_limit=1)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Using Gamma for hybrid agents  = 0.5
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 1 seconds, only 1028 combinations where tested
# Total time to compute costs:1.00 s
#  => The minimal cost is :  85.0
#  => The optimal paths are :  [[8, 11], [6, 3], [4, 3, 2, 5], [11, 9, 12], [1, 3, 6], [7, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=500, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [8, 11], 'cost': 4.0}
# sto2   {'path': [6, 3], 'cost': 7.0}
# adv1   {'path': [4, 3, 2, 5], 'cost': 43.0}
# adv2   {'path': [11, 8, 9, 10, 12], 'cost': 24.0}
# hyb1   {'path': [1, 3, 2, 5, 6], 'cost': 56.0}
# hyb2   {'path': [7, 6], 'cost': 9.0}
# Final total cost on the network : 143.0
# ****************************************************************************************************************************
# Using Gamma for hybrid agents  = 1
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 1 seconds, only 1146 combinations where tested
# Total time to compute costs:1.00 s
#  => The minimal cost is :  85.0
#  => The optimal paths are :  [[8, 11], [6, 3], [4, 3, 2, 5], [11, 9, 12], [1, 3, 6], [7, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=500, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [8, 11], 'cost': 4.0}
# sto2   {'path': [6, 3], 'cost': 7.0}
# adv1   {'path': [4, 7, 6, 5], 'cost': 25.0}
# adv2   {'path': [11, 8, 9, 10, 12], 'cost': 24.0}
# hyb1   {'path': [1, 3, 2, 5, 6], 'cost': 38.0}
# hyb2   {'path': [7, 6], 'cost': 9.0}
# Final total cost on the network : 107.0
# ****************************************************************************************************************************
# Using Gamma for hybrid agents  = 3
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 1 seconds, only 966 combinations where tested
# Total time to compute costs:1.00 s
#  => The minimal cost is :  85.0
#  => The optimal paths are :  [[8, 11], [6, 3], [4, 3, 2, 5], [11, 9, 12], [1, 3, 6], [7, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=500, style=ProgressStyle(description_width='…
# Paths found by the agents :
# sto1   {'path': [8, 11], 'cost': 2.0}
# sto2   {'path': [6, 3], 'cost': 7.0}
# adv1   {'path': [4, 3, 6, 5], 'cost': 23.0}
# adv2   {'path': [11, 9, 12], 'cost': 24.0}
# hyb1   {'path': [1, 3, 7, 10, 6], 'cost': 36.0}
# hyb2   {'path': [7, 4, 3, 6], 'cost': 21.0}
# Final total cost on the network : 113.0
# ****************************************************************************************************************************
# Using Gamma for hybrid agents  = 7
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 1 seconds, only 1052 combinations where tested
# Total time to compute costs:1.00 s
#  => The minimal cost is :  85.0
#  => The optimal paths are :  [[8, 11], [6, 3], [4, 3, 2, 5], [11, 9, 12], [1, 3, 6], [7, 6]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=500, style=ProgressStyle(description_width='…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c607c9abd674> in <module>()
#      12         summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=500, n_sto=n_players, n_adv=n_players, n_hyb=n_players,
#      13                                    n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
# ---> 14                                 gamma_hyb=gamma, time_limit=1)
#      15
#
# ~\Documents\GitHub\GML_Project\run_experiment.py in run_experiment_compar(g, adj_matrix, all_edges, assignement_type, assignement_dests, nb_iterations, n_sto, n_adv, n_hyb, n_rand, n_fix, exploration_parameter_stoc, lr_type_exp2, eta_hyb, Bt_hyb, use_adaptif_lr_hyb, gamma_hyb, time_limit)
#     198                                                    lr_type=lr_type_exp2
#     199                                                   )
# --> 200                     tracker_probas_over_arms_adv[agent_name] = agent_class.update_own_statistics()
#     201
#     202     print("Paths found by the agents :")
#
# ~\Documents\GitHub\GML_Project\Agents\Exp2_agent.py in update_own_statistics(self)
#      60
#      61         for j, arm in enumerate(self.arms_adv):
# ---> 62             self.new_proba_over_arms[j] = np.exp(-self.lr * np.dot(self.edge_presence_in_arm_indexes[:,j], zhat)) * self.old_proba_over_arms[j]
#      63
#      64         self.new_proba_over_arms = self.new_proba_over_arms / self.new_proba_over_arms.sum()
#
# KeyboardInterrupt:

# %% [markdown]
# **Impact of Bt parameter for Hybrid agent**

# %%
n_players = 2
B_ts = [0.01, 0.1, 0.5, 1, 2]
graph = 'OW'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.85)
for i, Bt in enumerate(B_ts) : 
    print('Using B_t for hybrid agents  = {}'.format(Bt), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=Bt, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=40)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=Bt, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=40)

# %% [markdown]
# **Comparing the behavior of algorithms when adding random agents**

# %%
n_players = 1
n_rnd_agents = [1, 2, 5, 8, 10]
graph = 'Random_Sparse_graph'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.8)
for i, n_randx in enumerate(n_rnd_agents) : 
    print('Number of agents with random path = {}'.format(n_randx), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                                gamma_hyb=1., time_limit=30)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=100, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
                                gamma_hyb=1., time_limit=30)
# Out:
# Graph creation...
# Graph creation : Done
# -------------------------------------------------------------------------------------------
# Number of agents with random path = 1
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 30 seconds, only 13185 combinations where tested
# Total time to compute costs:30.01 s
#  => The minimal cost is :  7.0
#  => The optimal paths are :  [[4, 10], [14, 3, 5, 11], [3, 18, 19], [16, 10]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=40, style=ProgressStyle(description_width='i…
# Paths found by the agents :
# sto1   {'path': [4, 10], 'cost': 1.0}
# adv1   {'path': [14, 8, 4, 10, 16, 1, 17, 6, 3, 13, 2, 18, 19, 12, 9, 7, 5, 15, 11], 'cost': 18.0}
# hyb1   {'path': [3, 14, 10, 1, 11, 15, 5, 7, 9, 12, 19], 'cost': 10.0}
# Final total cost on the network : 29.0
# ****************************************************************************************************************************
# Number of agents with random path = 2
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 30 seconds, only 15804 combinations where tested
# Total time to compute costs:30.00 s
#  => The minimal cost is :  13.0
#  => The optimal paths are :  [[4, 10], [14, 3, 5, 11], [3, 18, 19], [12, 1, 15, 2], [14, 3, 13]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=40, style=ProgressStyle(description_width='i…
# Paths found by the agents :
# sto1   {'path': [4, 10], 'cost': 1.0}
# adv1   {'path': [14, 9, 12, 7, 15, 13, 2, 18, 19, 17, 1, 16, 10, 4, 6, 3, 5, 11], 'cost': 17.0}
# hyb1   {'path': [3, 13, 2, 15, 11, 12, 7, 5, 9, 14, 10, 1, 19], 'cost': 12.0}
# Final total cost on the network : 30.0
# ****************************************************************************************************************************
# Number of agents with random path = 5
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# Agents creation, fixed (start, destination) assignment and all possible paths computation  : Done
# -------------------------------------------------------------------------------------------
# Oracle calculations ==> Global optimal paths and costs...
# Time depassed 30 seconds, only 11940 combinations where tested
# Total time to compute costs:30.01 s
#  => The minimal cost is :  25.0
#  => The optimal paths are :  [[4, 10], [14, 3, 5, 11], [3, 18, 19], [18, 1, 10, 4], [17, 1, 9, 7], [18, 1, 9, 7], [1, 15], [7, 9, 14, 8]]
# Oracle calculations ==> Global optimal paths and costs : Done
# -------------------------------------------------------------------------------------------
# HBox(children=(IntProgress(value=0, description='Simulation', max=40, style=ProgressStyle(description_width='i…
# Paths found by the agents :
# sto1   {'path': [4, 10], 'cost': 1.0}
# adv1   {'path': [14, 9, 7, 5, 3, 18, 2, 13, 15, 16, 1, 10, 4, 6, 17, 19, 12, 11], 'cost': 17.0}
# hyb1   {'path': [3, 5, 15, 16, 12, 7, 9, 14, 10, 1, 19], 'cost': 11.0}
# Final total cost on the network : 29.0
# ****************************************************************************************************************************
# Number of agents with random path = 8
# Agents creation, fixed (start, destination) assignment and all possible paths computation ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-c2224d416a06> in <module>()
#      12         summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=40, n_sto=n_players, n_adv=n_players, n_hyb=n_players,
#      13                                    n_rand=n_randx, n_fix=0, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=False,
# ---> 14                                 gamma_hyb=1., time_limit=30)
#      15
#
# ~\Documents\GitHub\GML_Project\run_experiment.py in run_experiment_compar(g, adj_matrix, all_edges, assignement_type, assignement_dests, nb_iterations, n_sto, n_adv, n_hyb, n_rand, n_fix, exploration_parameter_stoc, eta_hyb, Bt_hyb, use_adaptif_lr_hyb, gamma_hyb, time_limit)
#      68     else :
#      69         assignement_dests_ = assignement_dests
# ---> 70         assignement_dests_other = get_orig_dest(g, size=len(agents_random + agents_fixed))
#      71         agents_dicts = assignement.defined_assignement(list_destinations=assignement_dests_ + assignement_dests_other)
#      72
#
# ~\Documents\GitHub\GML_Project\run_experiment.py in get_orig_dest(graph, size)
#      18                 start, destination = np.random.choice(list(graph.vertices.keys()), replace = False, size = 2)
#      19
# ---> 20                 if (len(graph.getAllPaths(start, destination)) > 0) and ((start, destination) not in list_des):
#      21                     Path_not_exists = False
#      22             list_des.append((start, destination))
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in getAllPaths(self, start, end)
#      62
#      63     def getAllPaths(self, start, end):
# ---> 64        return self.dfs(start, end, [], [], [])
#      65
#      66     def getAllPathsSorted(self, start, end):
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      86            if i not in visited:
#      87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
# ---> 88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#      90        # continue finding paths by popping path and visited to get accurate paths
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in dfs(self, currVertex, destVertex, visited, path, fullPath)
#      85        for i in vertex.get_connections():
#      86            if i not in visited:
# ---> 87                self.vertices[i].currCost = vertex.get_cost(i) + vertex.currCost
#      88                self.dfs(i, destVertex, visited, path, fullPath)
#      89
#
# ~\Documents\GitHub\GML_Project\Environment\Env.py in get_cost(self, vertex)
#      27        return self.adjancencyList.keys()
#      28
# ---> 29     def get_cost(self, vertex):
#      30        return self.adjancencyList[vertex]
#      31
#
# KeyboardInterrupt:

# %% [markdown]
# **Comparing the behavior of algorithms when adding fixed agents**

# %%
n_players = 1
n_fixd_agents = [1, 2, 5, 8, 10]
graph = 'Sioux_Falls'
g, adj_matrix, all_edges = create_graph(graph_type=graph, number_vertices=20, dropout_edge_rate=0.8)
for i, fixd in enumerate(n_fixd_agents) : 
    print('Number of agents with fixed path = {}'.format(fixd), end='\n')
    if i==0:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', nb_iterations=150, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=fixd, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=20)
    else:
        summary_experiences, dests = run_experiment_compar(g, adj_matrix, all_edges, assignement_type='fixed', assignement_dests=dests, nb_iterations=150, n_sto=n_players, n_adv=n_players, n_hyb=n_players, 
                                   n_rand=0, n_fix=fixd, exploration_parameter_stoc=5, eta_hyb=0.1, Bt_hyb=0.01, use_adaptif_lr_hyb=True,
                                gamma_hyb=1., time_limit=20)
